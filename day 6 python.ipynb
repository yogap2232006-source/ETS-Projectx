# %% [markdown]
# <a href="https://colab.research.google.com/github/yogap2232006-source/ETS-Projectx/blob/main/day%206%20python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 56;
b = "yoga";
c = 78.97;
print(type(a));
print(type(b));
print(type(c));
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
x = "sherin princy";
print(x[5:7]);
# Out:
# n

# %%
u = "sabari vasan dad velumurugan";
print(u.upper())
# Out:
# SABARI VASAN DAD VELUMURUGAN

# %%
k = "paal buti ";
z = "sabari ";
j = k+z;
print(j);
print(k.replace("b","k"));
# Out:
# paal buti sabari
# paal kuti

# %%
list=["WWE",123,998,"API","ROMAN"];
smalllist = [123,432,"gorila"];
print(list);
print(smalllist);
print(list[0]);
print(list[1:4]);
print(list[3:]);
print(smalllist*2);
print(list + smalllist);
# Out:
# ['WWE', 123, 998, 'API', 'ROMAN']
# [123, 432, 'gorila']
# WWE
# [123, 998, 'API']
# ['API', 'ROMAN']
# [123, 432, 'gorila', 123, 432, 'gorila']
# ['WWE', 123, 998, 'API', 'ROMAN', 123, 432, 'gorila']

# %%
list = ["www","rrr","ggg"];
list.append("lll");
print(list);
list.remove("www");
print(list);
# Out:
# ['www', 'rrr', 'ggg', 'lll']
# ['rrr', 'ggg', 'lll']

# %%
op = ["sa","ri","ga","ma"];
op.sort();
print(op);
# Out:
# ['ga', 'ma', 'ri', 'sa']

# %%
ok = ["oa","yi","pa","ka"];
ok.sort(reverse=True)
print(op);
# Out:
# ['ga', 'ma', 'ri', 'sa']
