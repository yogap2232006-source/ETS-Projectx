# %% [markdown]
# <a href="https://colab.research.google.com/github/yogap2232006-source/ETS-Projectx/blob/main/Day_7_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tuple = ("yoga","maghesh","sherin","sabari")
print(tuple)
print(tuple[0:3])
print(tuple[3:])
print(tuple*2)
# Out:
# ('yoga', 'maghesh', 'sherin', 'sabari')
# ('yoga', 'maghesh', 'sherin')
# ('sabari',)
# ('yoga', 'maghesh', 'sherin', 'sabari', 'yoga', 'maghesh', 'sherin', 'sabari')

# %%
dict ={
    "brand":"str",
    "model":"demon",
    "year":1970
}
print(dict)
dict.update({"model":"challenger"})
print(dict)
# Out:
# {'brand': 'str', 'model': 'demon', 'year': 1970}
# {'brand': 'str', 'model': 'challenger', 'year': 1970}

# %%
a=5
b=10
print(a+b)
c=a+b
print(c)
# Out:
# 15
# 15

# %%
a=int(input("value"))
b=int(input("value"))
c=a+b
print(c)
print(type(c))
# Out:
# value6
# value7
# 13
# <class 'int'>

# %%
a=5.5
b=10.2
print(a+b)
c=a+b
print(c)
print(type(c))
# Out:
# 15.7
# 15.7
# <class 'float'>

# %%
str1="hello world"
print(str1)
print(len(str1))
print(str1[4])
print(str1[1:5])
# Out:
# hello world
# 11
# o
# ello

# %%
l=[1,2.2,'hello',"a"]
print(l)
print(type(l))
print(len(l))
print(l[2])
print(l[2:4])
l[3]="apple"
print(l)
# Out:
# [1, 2.2, 'hello', 'a']
# <class 'list'>
# 4
# hello
# ['hello', 'a']
# [1, 2.2, 'hello', 'apple']

# %%
t=(1,2.2,'hello','b')
print(t)
print(t[2])
print(t[1:3])
# Out:
# (1, 2.2, 'hello', 'b')
# hello
# (2.2, 'hello')

# %%
d={"a":"apple","b":"ball","c":"cat",'d':'dog'}
print(d)
print(d['a'])
d['b']="bat"
print(d)
d['e']='elephant'
print(d)
# Out:
# {'a': 'apple', 'b': 'ball', 'c': 'cat', 'd': 'dog'}
# apple
# {'a': 'apple', 'b': 'bat', 'c': 'cat', 'd': 'dog'}
# {'a': 'apple', 'b': 'bat', 'c': 'cat', 'd': 'dog', 'e': 'elephant'}

# %%
a = ["zebra","cat","apple"]
print(a[2],a[1],a[0])
# Out:
# apple cat zebra
